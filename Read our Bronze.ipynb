# %%
# 1. Leer los archivos Parquet desde tu ruta Bronze
df_yellow = spark.read.parquet("/Workspace/Shared/bronze/yellow_tripdata_2026_01.parquet")
df_green = spark.read.parquet("/Workspace/Shared/bronze/green_tripdata_2026_01.parquet")
df_fhv = spark.read.parquet("/Workspace/Shared/bronze/fhv_tripdata_2026_01.parquet")
df_fhvhv = spark.read.parquet("/Workspace/Shared/bronze/fhvhv_tripdata_2026_01.parquet")

# 2. Imprimir los esquemas para comparar sus estructuras
print("=== ESQUEMA YELLOW TAXI ===")
df_yellow.printSchema()

print("\n=== ESQUEMA GREEN TAXI ===")
df_green.printSchema()

print("\n=== ESQUEMA FHV TAXI===")
df_fhv.printSchema()

print("\n=== ESQUEMA FHVHV TAXI===")
df_fhvhv.printSchema()
